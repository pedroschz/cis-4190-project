# %% [markdown]
# # 05 — RoBERTa-base fine-tuning (stretch goal, Colab GPU)
#
# Same recipe as DistilBERT, slightly stronger model. Expected ~82-85% accuracy on the random split.
# Run only after DistilBERT is locked in.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %pip install -q transformers==4.45.* datasets accelerate evaluate

# %%
# !python -m src.models.transformer \
    --model roberta-base \
    --split random \
    --epochs 3 --batch-size 32 --lr 2e-5 --max-length 128 \
    --output-dir /content/drive/MyDrive/cis5190/runs/roberta_v1

# %%
# !python -m src.models.transformer \
    --model roberta-base \
    --split temporal \
    --epochs 3 --batch-size 32 --lr 2e-5 --max-length 128 \
    --output-dir /content/drive/MyDrive/cis5190/runs/roberta_temporal
