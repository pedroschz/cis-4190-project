# %% [markdown]
# # 03 — Classical baseline (TF-IDF + LR)
#
# v0 must reproduce the course baseline (~66.5%) — that's our pipeline sanity check.
# v1 and v2 are our improved classical baselines.

# %%
# !python -m src.models.classical --variant v0 --split random

# %%
# !python -m src.models.classical --variant v1 --split random

# %%
# !python -m src.models.classical --variant v2 --split random

# %%
import pandas as pd
pd.read_csv('reports/figures/results_table.csv')

# %% [markdown]
# Also run the best classical on the temporal split — needed for the temporal-decay analysis.

# %%
# !python -m src.models.classical --variant v2 --split temporal
